# %% [markdown]
# # Modeling - 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from utils.utils import *
from utils.modeling import *
from preprocess.pipe1 import PreprocessingV1

# %% [markdown]
# ### Preprocessing Pipeline 1

# %%
# Pre-preprocess
X_train, X_test, y_train, y_test = pre_preprocess()

# Preprocessing
preprocessing = PreprocessingV1()
X_train_proc = preprocessing.fit_transform(X_train)
X_test_proc = preprocessing.transform(X_test)

X_train_proc
# Out:
# X_train: (81322, 6), y_train: (81322,), X_test: (14352, 6), y_test: (14352,)
#        num__num_unique_upc  num__avg_scancount  num__total_scancount  \
# 74630            -0.663062           -0.038488             -0.632608
# 61468            -0.663062           -3.064435             -0.827308
# 10207            -0.424896           -0.038488             -0.437909
# 25328             0.765932           -0.038488              0.535589
# 15352             0.408683           -0.038488              0.243540
# ...                    ...                 ...                   ...
# 57115             0.051435            0.177651              0.048840
# 360              -0.663062            1.474485             -0.535258
# 89473            -0.067648           -0.254627             -0.145859
# 51195             0.051435           -0.038488             -0.048510
# 76280             0.289600            0.297728              0.340889
#
#        num__num_unique_dept  num__num_unique_fileline  cat__weekday_Friday  \
# 74630             -0.823057                 -0.666973                  0.0
# 61468             -0.823057                 -0.666973                  0.0
# 10207             -0.473153                 -0.393816                  0.0
# 25328              1.976168                  0.835391                  0.0
# 15352              0.576556                  0.562234                  0.0
# ...                     ...                       ...                  ...
# 57115             -0.123250                 -0.120659                  0.0
# 360               -0.823057                 -0.666973                  1.0
# 89473             -0.123250                 -0.393816                  0.0
# 51195              0.226653                  0.015920                  0.0
# 76280              0.576556                  0.152498                  0.0
#
#        cat__weekday_Monday  cat__weekday_Saturday  cat__weekday_Sunday  \
# 74630                  0.0                    0.0                  1.0
# 61468                  0.0                    0.0                  0.0
# 10207                  1.0                    0.0                  0.0
# 25328                  0.0                    1.0                  0.0
# 15352                  0.0                    0.0                  0.0
# ...                    ...                    ...                  ...
# 57115                  0.0                    0.0                  0.0
# 360                    0.0                    0.0                  0.0
# 89473                  0.0                    1.0                  0.0
# 51195                  0.0                    0.0                  1.0
# 76280                  1.0                    0.0                  0.0
#
#        cat__weekday_Thursday  cat__weekday_Tuesday  cat__weekday_Wednesday
# 74630                    0.0                   0.0                     0.0
# 61468                    0.0                   0.0                     1.0
# 10207                    0.0                   0.0                     0.0
# 25328                    0.0                   0.0                     0.0
# 15352                    0.0                   1.0                     0.0
# ...                      ...                   ...                     ...
# 57115                    0.0                   1.0                     0.0
# 360                      0.0                   0.0                     0.0
# 89473                    0.0                   0.0                     0.0
# 51195                    0.0                   0.0                     0.0
# 76280                    0.0                   0.0                     0.0
#
# [81322 rows x 12 columns]

# %%
# Train on 3 models
results_df = train_model(X_train_proc, y_train, X_test_proc, y_test)
results_df
# Out:
# Running Logistic Regression...
# Running Random Forest...
# Running XGBoost...
